# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabbyzuck/data-analytics-2025/blob/main/week7day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercise 1: Identifying Data Types
#
# A) A company's financial reports stored in an excel: Structured Data
#
# B) Photographs uploaded to a social media platform: Unstructured Data
#
# C) A collection of news articles on a website: Unstructured Data
#
# D) Inventory data in a relational database: Structured Data
#
# E) Recorded interviews from a market research study: Unstructured Data

# %% [markdown]
# Exercise 2: Transformation Exercise
#
# A) A series of blog posts about travel expereinces: Organize a database by different destinations and inside each destination, insert the correlated text about the travel experience.
#
# B) Audio recordings of customer service calls: Separate the call category into files of various customer requests and add a mecahnism to check if customers request had been satisfies.
#
# C) Handwritten notes from a branstorming session: Copy the notes into a file and save to a Brainstorming Folder.
#
# D) A video tutorial on cooking: Save the video file to the folder on that dish and transcibe the audio to the file to search for tutorials by text.

# %%
#Exercise 3: Import A File From Kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-6852b7fa-1aec-4d6a-aa67-24f0524aeb20" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6852b7fa-1aec-4d6a-aa67-24f0524aeb20">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip train.zip
# Out:
# Archive:  train.zip
#   inflating: train.csv

# %%
import pandas as pd
df = pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Exercise 4: Importing A CSV File

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-39ad884c-c7fe-4347-b405-299a25fc17a2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-39ad884c-c7fe-4347-b405-299a25fc17a2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip Iris_dataset.zip
# Out:
# Archive:  Iris_dataset.zip
#   inflating: Iris_dataset.csv

# %%
import pandas as pd
df = pd.read_csv('Iris_dataset.csv')
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
#Exercise 5: Export A Dataframe To Excel Format And JSON Format

# %%
simple_df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
simple_df.to_csv('simple_df.csv')

# %%
simple_df.to_json('simple_df.json')

# %%
#Exercise 6: Reading JSON Data

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-41fa1b3e-58b6-4387-a821-46c4e977a056" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-41fa1b3e-58b6-4387-a821-46c4e977a056">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip posts.zip
# Out:
# Archive:  posts.zip
#   inflating: posts.json

# %%
import pandas as pd
df = pd.read_json('posts.json')
df.head()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...
